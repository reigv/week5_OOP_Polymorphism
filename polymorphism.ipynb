# %% [markdown]
# # Week 5
#
#
# ### wtha is poly mor phiSm
# - so the meaniing is "---------many forms-----"
# - the ability to treat **value**, **objects**, **functions** in a ----uniform way----
# - italso allow the same interface, such as a function name or operator, to have **different behaviors** depending onthe context
# - reduce the strict coupling between types and operations

# %% [markdown]
# ### benefits
#
# - code reuse --- 1 implementation for many
# - up uP UP ---> maintainability --- because changes are all make in 1 place
# - the code is more **expressive & flexible** ---> easier to write and explain

# %% [markdown]
# ### Mono morphic Vs Polymorphic
#
# - mono ->> object tuype cannot be changed during the lifetime
# - mono ->> require seperate code for each type, ---even logic is the same----
# - example, needing the multiple ver. of sort()
# - poly language relax the strict link between types and func (operator)

# %% [markdown]
# ### Mono morphic in c++
#
# - intro **controlled ambiguity** ,, enable type variant in its lifetime
# - the flexibility --> close to natural language usage
# - in c++ -- objects are monomorphic (default)  ---- can be enable the polymorphic

# %% [markdown]
# ### type of polymorphism
#
# - in c++ , polymorphism --->> 2 board categories
#     1. Ad-hoc polymorphism: -----coercion---- && ----overloading-----
#     2. Universal polymorphism: -----inclusion----- && ----parametric-----

# %% [markdown]
# ### Ad-hoc polymorphism
#
# - work on finite set ( different & unrelated (potentially) ----types----- )
#     1. coercion: let compiiler to auto *convert type to another*  (implicit type conversion)
#     2. overloading: fnc and oprator to **share name** differ in parameter types

# %% [markdown]
# ### universal polymorphism
#
# - works on potential infinite num of types aross common str
#     1. inclusion ----- achieve through *inheritance and virtual fnc*
#     2. parametric -----**template**------ enable fnc || classes to operate on anyt type

# %% [markdown]
# ### Early binding vs Dynamic binding
#
# - early binfing  (static binding) ---- func call is resolved at compile time
# - dynamic dispatch (late binding) ----- fnc call ____________ at runtime
#
# - in c++ overloading | coercion | parametric polymorphism ------ rely on early binding
# - **inclusion** polymorphism uses dynamic dispatches through virtual func

# %% [markdown]
# ### ----------AD_HOC------------
#
# - coercion polymorphism ----- when c++ converts a value from 1 type to another
# - coercion ---> broader ----- such as converting int to double,
# - can be also be narrower, converting from douible to int ----- whhich may lose info afterward
# - most freq invol numerical types, during arithmetic exressions and fnc call

# %%
#include <iostream>

void printTotal(int total) {
    std::cout << "Total: " << total << std::endl;
}

int main() {

    int units = 3;
    double pricePerUnit = 19.99;

    double total = units * pricePerUnit;   // int -> double

    printTotal(total); // double-> int

    return 0;
}
